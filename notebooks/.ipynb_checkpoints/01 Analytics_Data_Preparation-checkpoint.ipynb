# %% [markdown]
# ## Zomato Bangalore Restaurants Prediction
# The basic idea of analyzing the Zomato dataset is to get a fair idea about the factors affecting the establishment
# of different types of restaurant at different places in Bengalur.

# %%
DF_PATH = '../data/raw/zomato.csv'
DF_SAVE_PATH = '../data/processed/analytics_zomato_processed.csv'

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# **To do list:**
# - Drop unneeded features: (url, address, phone, dish_liked, reviews_list, menu_item).
# - Fix (rate, approx_cost) features problems.
# - Remove duplicated rows.
# - Save the prepared data into csv file.

# %% [markdown]
# ----------------------

# %% [markdown]
# ### Read dataframe

# %%
df = pd.read_csv(DF_PATH)
df.sample(3)
# Out:
#                                                      url  \
# 15094  https://www.zomato.com/bangalore/driven-cafe-r...
# 3895   https://www.zomato.com/bangalore/the-nosh-hous...
# 39195  https://www.zomato.com/bangalore/sln-lunch-hom...
#
#                                                  address            name  \
# 15094  41/42, Residency Road, Bangalore Shanthala Nag...     Driven Cafe
# 3895   29, 1st Floor, 4th Cross, Kasavanahalli, Off S...  The Nosh House
# 39195  45/2, Sunkalpet Main Road, City Market, Bangalore  SLN Lunch Home
#
#       online_order book_table    rate  votes  \
# 15094          Yes         No   3.4/5    122
# 3895           Yes         No   4.3/5    220
# 39195           No         No  3.9 /5     28
#
#                                   phone        location    rest_type  \
# 15094  +91 9513344707\r\n+91 9160018419  Residency Road         Cafe
# 3895                     +91 9980299910   Sarjapur Road     Delivery
# 39195                      080 22230324     City Market  Quick Bites
#
#                                               dish_liked  \
# 15094        Coffee, Fries, Cappuccino, Margherita Pizza
# 3895   Sandwich, Pancakes, Sandwiches, Pasta, Waffles...
# 39195                                                NaN
#
#                                                 cuisines  \
# 15094                         Cafe, Beverages, Fast Food
# 3895   American, Italian, Bakery, Desserts, Sandwich,...
# 39195                                       South Indian
#
#       approx_cost(for two people)  \
# 15094                         600
# 3895                          600
# 39195                         100
#
#                                             reviews_list  \
# 15094  [('Rated 1.0', "RATED\n  Really BAD restaurant...
# 3895   [('Rated 3.0', 'RATED\n  I have ordered breakf...
# 39195  [('Rated 4.0', 'RATED\n  Visited this place to...
#
#                                                menu_item listed_in(type)  \
# 15094  ['Alfredo Pasta', 'Pesto Pasta', 'Red Sauce Pa...        Delivery
# 3895   ['Mixed Berry Breakfast Parfait', 'Classic Pan...        Delivery
# 39195                                                 []        Dine-out
#
#       listed_in(city)
# 15094     Frazer Town
# 3895        Bellandur
# 39195    Lavelle Road

# %% [markdown]
# ### Drop unneeded features: (url, address, phone, dish_liked, reviews_list, menu_item)

# %%
cols_to_drop = ['url', 'address', 'phone', 'dish_liked', 'reviews_list', 'menu_item']
df.drop(cols_to_drop, axis = 1, inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51717 non-null  object
#  1   online_order                 51717 non-null  object
#  2   book_table                   51717 non-null  object
#  3   rate                         43942 non-null  object
#  4   votes                        51717 non-null  int64
#  5   location                     51696 non-null  object
#  6   rest_type                    51490 non-null  object
#  7   cuisines                     51672 non-null  object
#  8   approx_cost(for two people)  51371 non-null  object
#  9   listed_in(type)              51717 non-null  object
#  10  listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 4.3+ MB

# %% [markdown]
# ### Fix (rate, approx_cost) features problems.

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
def fix_rate(rate):
    try:
        return float(rate[0:3])
    except:
        return np.nan

# %%
df['rate'].apply(fix_rate).unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, nan, 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2,
#        2.3, 4.8, 4.9, 2.1, 2. , 1.8])

# %%
df['rate'] = df['rate'].apply(fix_rate)

# %%
df['rate'].describe()
# Out:
# count    41665.000000
# mean         3.700449
# std          0.440513
# min          1.800000
# 25%          3.400000
# 50%          3.700000
# 75%          4.000000
# max          4.900000
# Name: rate, dtype: float64

# %%
fig = px.box(data_frame = df, x = 'rate', color_discrete_sequence = ['#747264'])
fig.update_layout(height = 400, width = 550, plot_bgcolor = '#ffffff', font = dict(color = 'black'))
fig.update_xaxes(title = 'Outliers of Rate')
fig.show(renderer = 'svg')

# %% [markdown]
# >**Note:** The problem has been fixed, and this outliers are business outliers have meaning we can't drop it.

# %%
df['approx_cost(for two people)'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '50', '190', '1,700', nan, '1,400', '180',
#        '1,350', '2,200', '2,000', '1,800', '1,900', '330', '2,500',
#        '2,100', '3,000', '2,800', '3,400', '40', '1,250', '3,500',
#        '4,000', '2,400', '2,600', '120', '1,450', '469', '70', '3,200',
#        '60', '560', '240', '360', '6,000', '1,050', '2,300', '4,100',
#        '5,000', '3,700', '1,650', '2,700', '4,500', '140'], dtype=object)

# %%
df['approx_cost(for two people)'].astype(str).apply(lambda c : float(c.replace(",", ""))).unique()
# Out:
# array([ 800.,  300.,  600.,  700.,  550.,  500.,  450.,  650.,  400.,
#         900.,  200.,  750.,  150.,  850.,  100., 1200.,  350.,  250.,
#         950., 1000., 1500., 1300.,  199.,   80., 1100.,  160., 1600.,
#         230.,  130.,   50.,  190., 1700.,   nan, 1400.,  180., 1350.,
#        2200., 2000., 1800., 1900.,  330., 2500., 2100., 3000., 2800.,
#        3400.,   40., 1250., 3500., 4000., 2400., 2600.,  120., 1450.,
#         469.,   70., 3200.,   60.,  560.,  240.,  360., 6000., 1050.,
#        2300., 4100., 5000., 3700., 1650., 2700., 4500.,  140.])

# %%
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].astype(str).apply(lambda c : float(c.replace(",", "")))

# %%
df['approx_cost(for two people)'].describe()
# Out:
# count    51371.000000
# mean       555.431566
# std        438.850728
# min         40.000000
# 25%        300.000000
# 50%        400.000000
# 75%        650.000000
# max       6000.000000
# Name: approx_cost(for two people), dtype: float64

# %%
fig = px.box(data_frame = df, x = 'approx_cost(for two people)', color_discrete_sequence = ['#747264'])
fig.update_layout(height = 400, width = 600, plot_bgcolor = '#ffffff', font = dict(color = 'black'))
fig.update_xaxes(title = 'Outliers of approx_cost(for two people)')
fig.show(renderer = 'svg')

# %% [markdown]
# >**Note:** Same as rate, the approx_cost problem has been solved, and it's outliers are needed.

# %% [markdown]
# ### Remove duplicated rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51717 non-null  object
#  1   online_order                 51717 non-null  object
#  2   book_table                   51717 non-null  object
#  3   rate                         41665 non-null  float64
#  4   votes                        51717 non-null  int64
#  5   location                     51696 non-null  object
#  6   rest_type                    51490 non-null  object
#  7   cuisines                     51672 non-null  object
#  8   approx_cost(for two people)  51371 non-null  float64
#  9   listed_in(type)              51717 non-null  object
#  10  listed_in(city)              51717 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 4.3+ MB

# %%
df.duplicated().sum()
# Out:
# 108

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Save the prepared data into csv file

# %%
df.to_csv(DF_SAVE_PATH, index = False)

# %% [markdown]
# **Conclusion:**
# - We fixed done our analytics preperation for data.
# - Next, To do is EDA and analytics.
